# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabellIngram751/MusicComputingIsabellIngram/blob/main/labassignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import IPython.display

# %%
def plotAudio2(sig,frequency,signal,samplingRate,numHarmonics,winSize,specType,waveType):


   # this version expects the audio file to have already been opened by librosa


   # Adjust the x-axis to represent time


   time=np.arange(0,sig.shape[0])/sampleRate


   # Scale the y-axis to represent amplitude from -1 to 1
   excursion=max(abs(sig))
   sigNew = sig / excursion


   # Label the x and y axes with variables
   xlabel = 'Time (seconds)'
   ylabel = 'Amplitude'


   #plot the signal using the x and y axis variables
   plt.plot(time,sigNew)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   plt.title(title)
   plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

  spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)),ref=np.max)
  librosa.display.specshow(spec, y_axis=specType)
  plt.colorbar(format='%+2.0f dB')
  plt.title(f'{specType} power spectrogram')
  plt.show()

# %%
def additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent):

   # from additiveSynthesis.ipynb

    # generate list of harmonics
    harmonics = np.arange(1,numHarmonics+1,seqHarm)
    harmonics = harmonics[1:-1]

    # create a time series from 0 to 1 the inputted length
    timeSeries = np.linspace(0, 1, samplingRate)

    # create a cosine wave for the fundamental
    signal = np.cos(2.0 * np.pi * frequency * timeSeries)

    # add harmonics based on the those specified in the variable 'harmonics'
    for harm in harmonics:
        signal = signal + np.cos(2.0 * np.pi * frequency * harm * timeSeries)/harm**ampExponent

    # scale the signal to between -1 and 1
    excursion=max(abs(signal))
    signal = signal / excursion

    # plot signal
    plt.plot(timeSeries,signal)
    plt.xlabel('Time (Sec)')
    plt.ylabel('Amplitude')
    plt.title('Additive Synthesis')
    plt.plot

    return signal

# %%
def makeWaveforms(frequency,samplingRate,numHarmonics,waveType):

    # use an if/elif/else statement to set up the parameters for
    # the different type of waveforms based on the code in
    # additiveSynthesis.ipynb
    # if, elif (else if) and else can be used to evaluate the contents of a variable


    # call additiveSynthesis() to generate a waveform

    # return the generated waveform (signal)
# if, elif (else if) and else can be used to evaluate the contents of a variable

 if waveType == 'sawtooth':
    seqHarm = 1
    ampExponent = 1
 elif waveType == 'square':
    seqHarm = 2
    ampExponent = 1
 elif waveType == 'triangle':
    seqHarm = 2
    ampExponent = 2
 else:
    numHarmonics = 1
    seqHarm = 1
    ampExponent = 1

    signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)

    return signal

# %%
def visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType, winSize, specType):
   # call makeWaveform()
   # test whether makeWaveforms() runs without error before you try plotting anything

   # call plotAudio2()
  plotAudio2(frequency,signal,samplingRate,numHarmonics,winSize,specType,waveType,winSize,specType)
  # call plotAudioFreqDomain()
  plotAudioFreqDomain(signal,samplingRate,numHarmonics,winSize,specType)
  # return the output of makeWaveform()
  return makeWaveforms

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sine'
winSize = 1024
specType = 'log'


#visualizeWaveforms()
#IPython.display.Audio()
IPython.display.Audio(data=signal,rate=samplingRate)
signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sawtooth'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()
signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
IPython.display.Audio(data=signal, rate=samplingRate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'triangle'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()
signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
IPython.display.Audio(data=signal, rate=samplingRate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'square'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()
signal2 = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
IPython.display.Audio(data=signal2, rate=samplingRate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Ya, I have no Clue on how to fix this and I dont understand any of this
# i kept getting so many errors and none I even know how to fix.
#  Why is the "time=np.arange(0,sig.shape[0])/sampleRate" part of cell 2 not working and it says "AttributeError: 'int' object has no attribute 'shape'"
#  I have no clue.
#  or it says "TypeError: plotAudio2() takes 8 positional arguments but 9 were given"
#  This is genuinely the best I can do right now because the slides and zoom call video does not help me ;-;

# %%
frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'square'
winSize = 1024
specType = 'log'

#visualizeWaveforms()
#IPython.display.Audio()
visualizeWaveforms(frequency,samplingRate,numHarmonics,waveType,winSize,specType)
signal2 = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
IPython.display.Audio(data=signal2, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_176/3466888544.py in <cell line: 0>()
#       8 #visualizeWaveforms()
#       9 #IPython.display.Audio()
# ---> 10 visualizeWaveforms(frequency,samplingRate,numHarmonics,waveType,winSize,specType)
#      11 signal2 = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)
#      12 IPython.display.Audio(data=signal2, rate=samplingRate)
#
# /tmp/ipykernel_176/3517036785.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, waveType, winSize, specType)
#       4
#       5    # call plotAudio2()
# ----> 6   plotAudio2(frequency,signal,samplingRate,numHarmonics,winSize,specType,waveType,winSize,specType)
#       7   # call plotAudioFreqDomain()
#       8   plotAudioFreqDomain(signal,samplingRate,numHarmonics,winSize,specType)
#
# TypeError: plotAudio2() takes 8 positional arguments but 9 were given

# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabellIngram751/MusicComputingIsabellIngram/blob/main/labAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 130 (delta 28), reused 18 (delta 18), pack-reused 96 (from 1)
# Receiving objects: 100% (130/130), 16.27 MiB | 19.70 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# **44100 Sample Rate:**

# %%
file = 'imc2023/audioFiles/avm2.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
xlabel = 'time (seconds)'
ylabel = 'Amplitude'

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %% [markdown]
# **441 Sample Rate:**

# %%
file = 'imc2023/audioFiles/avm2.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
xlabel = 'time (seconds)'
ylabel = 'Amplitude'

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
